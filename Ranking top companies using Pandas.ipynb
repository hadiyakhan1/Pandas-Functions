# %%
#For importing csv file 
import pandas as pd
#Jupyter Notebook file and .csv file should be on the same location else full location should be given in the below line 
df = pd.read_csv('2022_Forbes_list.csv')
df
# Out:
#     Unnamed: 0  Rank in India Changes Rank from last Year  \
# 0            0              1                         (0)
# 1            1              2                         (0)
# 2            2              3                         (0)
# 3            3              4                         (0)
# 4            4              5                        (+8)
# 5            5              6                        (-1)
# 6            6              7                        (+5)
# 7            7              8                        (-2)
# 8            8              9                       (+18)
# 9            9             10                        (+1)
# 10          10             11                        (-1)
# 11          11             12                        (-5)
# 12          12             13                        (-4)
# 13          13             14                       (+12)
# 14          14             15                       (+18)
# ...

# %%
#for finding particular data from particular line number(index number)
import pandas as pd
df = pd.read_csv('2022_Forbes_list.csv')
df.loc[1]
# Out:
# Unnamed: 0                                         1
# Rank in India                                      2
# Changes Rank from last Year                      (0)
# Forbes 2000 rank in World                        105
# Changes Rank from last Year.1                   (+5)
# Name                             State Bank of India
# Headquarters                                  Mumbai
# Revenue(billions US$)                          54.52
# Profit(billions US$)                            4.32
# Assets(billions US$)                          696.51
# Value(billions US$)                            58.39
# Industry                                     Banking
# Name: 1, dtype: object

# %%
#for fetching only top 5 data from list
import pandas as pd
df=pd.read_csv('2022_Forbes_list.csv')
df.head(5)
# Out:
#    Unnamed: 0  Rank in India Changes Rank from last Year  \
# 0           0              1                         (0)
# 1           1              2                         (0)
# 2           2              3                         (0)
# 3           3              4                         (0)
# 4           4              5                        (+8)
#
#    Forbes 2000 rank in World Changes Rank from last Year.1  \
# 0                         54                          (+1)
# 1                        105                          (+5)
# 2                        154                         (-38)
# 3                        205                         (-23)
# 4                        229                        (+426)
#
#                               Name Headquarters  Revenue(billions US$)  \
# 0              Reliance Industries       Mumbai                  86.85
# 1              State Bank of India       Mumbai                  54.52
# ...

# %%
#for fetching only bottom 5 data from list
import pandas as pd
df=pd.read_csv('2022_Forbes_list.csv')
df.tail(5)
# Out:
#     Unnamed: 0  Rank in India Changes Rank from last Year  \
# 45          45             46                        (+4)
# 46          46             47                        (-5)
# 47          47             48                        (+2)
# 48          48             49                        (-8)
# 49          49             50                         (0)
#
#     Forbes 2000 rank in World Changes Rank from last Year.1  \
# 45                       1705                        (+295)
# 46                       1730                         (-87)
# 47                       1746                        (+254)
# 48                       1756                        (-136)
# 49                       1759                        (+208)
#
#                   Name Headquarters  Revenue(billions US$)  \
# 45  Adani Transmission    Ahmedabad                   1.49
# 46       Tech Mahindra         Pune                   5.72
# 47     Adani Total Gas    Ahmedabad                   0.35
# ...

# %%
#for finding lenght of the data
import pandas as pd
df=pd.read_csv('2022_Forbes_list.csv')
len(df)
# Out:
# 50

# %%
#for fetching similar data
import pandas as pd
df=pd.read_csv('2022_Forbes_list.csv')
df.query("Headquarters == 'Ahmedabad'")
# Out:
#     Unnamed: 0  Rank in India Changes Rank from last Year  \
# 38          38             39                       (+11)
# 41          41             42                        (-6)
# 42          42             43                        (+7)
# 45          45             46                        (+4)
# 47          47             48                        (+2)
#
#     Forbes 2000 rank in World Changes Rank from last Year.1  \
# 38                       1453                        (+547)
# 41                       1489                         (-78)
# 42                       1570                        (+430)
# 45                       1705                        (+295)
# 47                       1746                        (+254)
#
#                          Name Headquarters  Revenue(billions US$)  \
# 38          Adani Enterprises    Ahmedabad                   7.86
# 41  Adani Ports & SEZ Limited    Ahmedabad                   2.10
# ...

# %%
#for finding particular range of data
import pandas as pd
df = pd.read_csv('2022_Forbes_list.csv')
df.iloc[1:4]
# Out:
#    Unnamed: 0  Rank in India Changes Rank from last Year  \
# 1           1              2                         (0)
# 2           2              3                         (0)
# 3           3              4                         (0)
#
#    Forbes 2000 rank in World Changes Rank from last Year.1  \
# 1                        105                          (+5)
# 2                        154                         (-38)
# 3                        205                         (-23)
#
#                   Name Headquarters  Revenue(billions US$)  \
# 1  State Bank of India       Mumbai                  54.52
# 2            HDFC Bank       Mumbai                  22.51
# 3           ICICI Bank       Mumbai                  21.89
#
#    Profit(billions US$)  Assets(billions US$)  Value(billions US$) Industry
# 1                  4.32                696.51                58.39  Banking
# 2                  5.11                280.16                98.28  Banking
# ...

# %%
#for fetching the maximum value from particular column
df['Revenue(billions US$)'].max()
# Out:
# 86.85

# %%
#for fetching the minimum value from particular column
df['Revenue(billions US$)'].min()
# Out:
# 0.35

# %%
#for fetching the total count of a particular column
df['Revenue(billions US$)'].count()
# Out:
# 50

# %%
#for calculating the sum of values of a particular column
df['Revenue(billions US$)'].sum()
# Out:
# 869.1800000000001

# %%
#for calculating the average of particular column
df['Revenue(billions US$)'].mean()
# Out:
# 17.383599999999998

# %%
#for Updating the column name
df.rename(columns={'Name':'Company Names'})
# Out:
#     Unnamed: 0  Rank in India Changes Rank from last Year  \
# 0            0              1                         (0)
# 1            1              2                         (0)
# 2            2              3                         (0)
# 3            3              4                         (0)
# 4            4              5                        (+8)
# 5            5              6                        (-1)
# 6            6              7                        (+5)
# 7            7              8                        (-2)
# 8            8              9                       (+18)
# 9            9             10                        (+1)
# 10          10             11                        (-1)
# 11          11             12                        (-5)
# 12          12             13                        (-4)
# 13          13             14                       (+12)
# 14          14             15                       (+18)
# ...
